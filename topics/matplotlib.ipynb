# %% [markdown]
# # Matplotlib

# %%
# install matplotlib (if not installed)

import sys

# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (4.28.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: setuptools-scm>=4 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: numpy>=1.17 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/danielhopfner/Library/Python/3.8/lib/python/site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib) (49.2.1)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## plot-function

# %%
import matplotlib.pyplot as plt

# %%
print(a)

plt.plot(a)
# Out:
# [ 1  3 49 81  5 67]

# %%
plt.plot(a, '.')

# %%
plt.plot(a, '.-')

# %%
plt.plot(a, 'ro')

# %%
# see https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
x = np.linspace(-20, 20, num=1000)

y_1 = x
y_2 = x ** 2
y_3 = x ** 3
y_4 = 1 / x ** 2

plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)
plt.plot(x, y_4)

# %% [markdown]
# ## xlim | ylim

# %%
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)
plt.plot(x, y_4)

plt.ylim(-200, 200)
plt.xlim(-20, 20)
# Out:
# (-20.0, 20.0)
